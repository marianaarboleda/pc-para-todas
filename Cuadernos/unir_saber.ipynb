# %% [markdown]
# <a href="https://colab.research.google.com/github/marianaarboleda/pc-para-todas/blob/master/Cuadernos/unir_saber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pruebas saber 11 vs saber pro
# Inicialmente descargué saber 11 del 2011 y saber pro del 2016 porque son los años en los que yo las tomé

# %% [markdown]
# ## 1. Saber 11

# %%
# !pip install openpyxl==3.1.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.8/249.8 kB 2.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.1.2
#     Uninstalling openpyxl-3.1.2:
#       Successfully uninstalled openpyxl-3.1.2
# ...

# %%
import pandas as pd
import plotly.express as px
from glob import glob
import openpyxl

# %% [markdown]
# ## 1.1 Leer y explorar

# %%
saber11 = pd.read_csv('SB11_20112.txt', sep='¬', engine='python',nrows=80000)
print('columnas df: ', saber11.shape)
saber11 = saber11.rename(columns={'ESTU_CONSECUTIVO':'ESTU_CONSECUTIVO_11'})
#saber11["FAMI_PERSONASHOGAR"] = saber11["FAMI_PERSONASHOGAR"].replace({""})
saber11
# Out:
# columnas df:  (80000, 116)
#       ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                     TI          COLOMBIA           F           07/06/1994
# 1                     TI          COLOMBIA           F           24/10/1994
# 2                     TI          COLOMBIA           M           14/08/1994
# 3                     TI          COLOMBIA           M           22/03/1995
# 4                     TI          COLOMBIA           M           10/02/1994
# ...                  ...               ...         ...                  ...
# 79995                 TI          COLOMBIA           F           22/09/1994
# 79996                 CC          COLOMBIA           M           09/12/1975
# 79997                 TI          COLOMBIA           F           29/09/1994
# 79998                 CC          COLOMBIA           F           06/03/1993
# 79999                 CC          COLOMBIA           F           12/07/1978
#
# ...

# %% [markdown]
# ## 1.2 Preparar

# %% [markdown]
# Limitemos las columnas para no estresarnos mucho

# %%
saber11.columns.tolist()
# Out:
# ['ESTU_TIPODOCUMENTO',
#  'ESTU_NACIONALIDAD',
#  'ESTU_GENERO',
#  'ESTU_FECHANACIMIENTO',
#  'PERIODO',
#  'ESTU_CONSECUTIVO_11',
#  'ESTU_ESTUDIANTE',
#  'ESTU_PAIS_RESIDE',
#  'ESTU_DEPTO_RESIDE',
#  'ESTU_COD_RESIDE_DEPTO',
#  'ESTU_MCPIO_RESIDE',
#  'ESTU_COD_RESIDE_MCPIO',
#  'ESTU_AREARESIDE',
#  'ESTU_MESTERMINOBACHILLER',
#  'ESTU_ANOTERMINOBACHILLER',
#  'ESTU_VALORPENSIONCOLEGIO',
#  'ESTU_MOTIVO_PRESENTAVALIDACION',
#  'ESTU_VECESPRESENTOEXAMEN',
#  'FAMI_EDUCACIONPADRE',
#  'FAMI_EDUCACIONMADRE',
#  'FAMI_OCUPACIONPADRE',
#  'FAMI_OCUPACIONMADRE',
#  'FAMI_ESTRATOVIVIENDA',
#  'FAMI_NIVELSISBEN',
#  'FAMI_PERSONASHOGAR',
#  'FAMI_CUARTOSHOGAR',
#  'FAMI_PISOSHOGAR',
#  'FAMI_TIENEINTERNET',
#  'FAMI_TIENE_SERVICIOTV',
#  'FAMI_TIENECOMPUTADOR',
#  'FAMI_TIENELAVADORA',
#  'FAMI_TIENEMICROONDAS',
#  'FAMI_TIENEHORNO',
#  'FAMI_TIENEAUTOMOVIL',
#  'FAMI_TIENEDVD',
#  'FAMI_TIENE_NEVERA',
#  'FAMI_TIENE_CELULAR',
#  'FAMI_TELEFONO',
#  'FAMI_INGRESOFMILIARMENSUAL',
# ...

# %%
sb11 = saber11.loc[:,
    [
        "ESTU_GENERO",
        "COLE_GENERO",

        "ESTU_CONSECUTIVO_11",
        "COLE_NATURALEZA",
        "FAMI_PERSONASHOGAR",
        "FAMI_CUARTOSHOGAR",
        "PUNT_MATEMATICAS",
        "PUNT_INGLES",
        "DESEMP_INGLES",
        "PUNT_CIENCIAS_SOCIALES",
        "PUNT_BIOLOGIA",
        "PUNT_FILOSOFIA",
        "PUNT_FISICA",
        "PUNT_QUIMICA",
        "PUNT_LENGUAJE",
        "ESTU_PUESTO",
    ],
]

# %%
#sb11.to_excel("sb11.xlsx")

# %%
sb11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ESTU_GENERO             79999 non-null  object
#  1   COLE_GENERO             79979 non-null  object
#  2   ESTU_CONSECUTIVO_11     80000 non-null  object
#  3   COLE_NATURALEZA         79979 non-null  object
#  4   FAMI_PERSONASHOGAR      78973 non-null  object
#  5   FAMI_CUARTOSHOGAR       78977 non-null  object
#  6   PUNT_MATEMATICAS        80000 non-null  int64
#  7   PUNT_INGLES             80000 non-null  int64
#  8   DESEMP_INGLES           79965 non-null  object
#  9   PUNT_CIENCIAS_SOCIALES  80000 non-null  int64
#  10  PUNT_BIOLOGIA           80000 non-null  int64
#  11  PUNT_FILOSOFIA          80000 non-null  int64
#  12  PUNT_FISICA             80000 non-null  int64
#  13  PUNT_QUIMICA            80000 non-null  int64
# ...

# %%
sb11
# Out:
#       ESTU_GENERO COLE_GENERO ESTU_CONSECUTIVO_11 COLE_NATURALEZA  \
# 0               F       MIXTO    SB11201120317654      NO OFICIAL
# 1               F       MIXTO    SB11201120317658      NO OFICIAL
# 2               M       MIXTO    SB11201120267303         OFICIAL
# 3               M       MIXTO    SB11201120560713      NO OFICIAL
# 4               M       MIXTO    SB11201120317667      NO OFICIAL
# ...           ...         ...                 ...             ...
# 79995           F       MIXTO    SB11201120429652         OFICIAL
# 79996           M       MIXTO    SB11201120429646         OFICIAL
# 79997           F       MIXTO    SB11201120429639         OFICIAL
# 79998           F       MIXTO    SB11201120429642         OFICIAL
# 79999           F       MIXTO    SB11201120429633         OFICIAL
#
#       FAMI_PERSONASHOGAR FAMI_CUARTOSHOGAR  PUNT_MATEMATICAS  PUNT_INGLES  \
# 0                    Dos               Dos                60           61
# ...

# %% [markdown]
# ## 1.3 Agrupar - visualizar

# %% [markdown]
# ### ¿Cómo se relacionan los puntajes en filosofía y lenguaje?

# %% [markdown]
# En este caso podemos ver un diagrama de dispersión, entonces no es necesario agrupar (AÚN)

# %%
fig_filosofia_lenguaje = px.scatter(sb11, x='PUNT_FILOSOFIA', y='PUNT_LENGUAJE')
fig_filosofia_lenguaje.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# PARECE HUEHUVIBHJZVJNSDKC

# %% [markdown]
# ### ¿Cómo se relacionan los puntajes de matemáticas y lenguaje?

# %%
## Tu código aquí

# %% [markdown]
# ### ¿Cuál es el puntaje promedio en matemáticas respecto al sexo?

# %%
## Tabla dinámica

# %%
## Gráfica
px.bar(sb11, x="ESTU_GENERO", y="PUNT_LENGUAJE")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### ¿Cuál es el puntaje promedio en matemáticas respecto al género de los estudiantes y el género del colegio?

# %%
## Tabla dinámica

# %%
## Gráfica
